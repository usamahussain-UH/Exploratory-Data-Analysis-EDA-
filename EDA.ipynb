# %%
# importing the Pandas and Numpy
import pandas as pd
import numpy as np
# importing the matplotlib and seaborn 
import matplotlib.pyplot as plt 
import seaborn as sns
# anyother lib

# %%
# loading the dataset
dataset=pd.read_csv("D:\Github_Repos\Exploratory-Data-Analysis-EDA-\diabetes.csv")

# %%
df=pd.DataFrame(dataset)

# %%
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age Outcome
# 0                       0.627   50       1
# ...

# %% [markdown]
# The whole dataset have the 768 samples(rows) and 9 features(columns)

# %%
# print the first 5 rows with data
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age Outcome
# 0                     0.627   50       1
# 1                     0.351   31       0
# 2                     0.672   32       1
# 3                     0.167   21       0
# 4                     2.288   33       1

# %%
# printing the columns 
print(df.columns)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='str')

# %%
# getting the more into below to understand the dataset

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    str
# dtypes: float64(2), int64(6), str(1)
# memory usage: 54.9 KB

# %%
df.describe(include='all')
# Out:
#         Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count    768.000000  768.000000     768.000000     768.000000  768.000000
# unique          NaN         NaN            NaN            NaN         NaN
# top             NaN         NaN            NaN            NaN         NaN
# freq            NaN         NaN            NaN            NaN         NaN
# mean       3.845052  120.894531      69.105469      20.536458   79.799479
# std        3.369578   31.972618      19.355807      15.952218  115.244002
# min        0.000000    0.000000       0.000000       0.000000    0.000000
# 25%        1.000000   99.000000      62.000000       0.000000    0.000000
# 50%        3.000000  117.000000      72.000000      23.000000   30.500000
# 75%        6.000000  140.250000      80.000000      32.000000  127.250000
# max       17.000000  199.000000     122.000000      99.000000  846.000000
#
#                BMI  DiabetesPedigreeFunction         Age Outcome
# ...

# %% [raw]
# There are several common measures of central tendency:
#
# Mean: The average value of the variable, calculated as the sum of all values divided by the number of values.
# Median: The middle value of the variable when sorted. Mode: The most frequent value of the variable.
# Trimmed mean: The mean excluding x percent of the lowest and highest data points.

# %%
# checking the null NAN values
print(df.isna().sum())
# or same 
#print(df.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print(df.shape)
# row , col
# Out:
# (768, 9)

# %%
# finding the common values/data/sample
# also works on numbers
print(df.Outcome.unique())
print(df.Pregnancies.unique())
# Out:
# <ArrowStringArray>
# ['1', '0', 'O']
# Length: 3, dtype: str
# [ 6  1  8  0  5  3 10  2  4  7  9 11 13 15 17 12 14]

# %%
#Trimmed mean = almost same as normal mean
# proportiontocut =removes % from each side (start and end)


from scipy import stats

stats.trim_mean(df['SkinThickness'], proportiontocut=0.2)
# Out:
# np.float64(20.296536796536795)

# %%
# the the percentage of the samples 
valuecount=df.Outcome.value_counts(normalize=True)
print(valuecount)
# Out:
# Outcome
# 0    0.643229
# 1    0.348958
# O    0.007812
# Name: proportion, dtype: float64

# %% [markdown]
# There are several common measures of spread:
#
# Range: The difference between the maximum and minimum values of a variable.
# Range = max(x) - min(x)
# Interquartile range (IQR): The difference between the 75th and 25th percentile values.
# IQR = Q3 - Q1
# (e.g) iqr_budget=df.Age.quantile(.75) - df['Age'].quantile(.25)
# Variance: The average of the squared distance from Preview: Docs Loading link description each data point to the mean.
#
# Standard deviation (SD): The square root of the variance.
#
# Mean absolute deviation (MAD): The mean absolute value of the distance between each data point and the mean.

# %% [raw]
# The pandas.crosstab() function computes a simple cross-tabulation (contingency table) of two or more factors or variables.
# By default, it builds a frequency table (counts of occurrences) of the factors, which is useful for analyzing the relationship
# between categorical variables.
# cross_tab = pd.crosstab(df['Gender'], df['Smoker'])
# print(cross_tab)
# '''
# Output
#
# Smoker  No  Yes
# Gender
# Female   2    0
# Male     1    2
# '''

# %% [raw]
# margin_all = pd.crosstab(df['Age'], df['Outcome'], normalize='index', margins=True)
# Marginal proportions in pandas represent the proportion of observations belonging to a single category of a variable,
# calculated by dividing row or column sums by the total number of observations in a contingency table.
# They provide an overall summary of a variable, ignoring other variables in a multi-variable dataset.

# %% [raw]
# The Chi-Square statistic in Python, often computed using scipy.stats.chi2_contingency on Pandas data,
# measures how observed categorical frequencies differ from expected frequencies.

# %% [markdown]
# # Create a boxplot

# %%
sns.boxplot(x='BloodPressure', data=df)
plt.show()
plt.clf()

# %% [markdown]
# # Create a histogram

# %%
sns.histplot(x='BloodPressure', data=df)
plt.show()
plt.close()

# %%
sns.countplot(x='Outcome',data=df)
plt.show()
plt.close()

sns.countplot(x='BMI',data=df)
plt.show()
plt.close()

# %%
df.Age.value_counts().plot.pie()
plt.show()
plt.close()

# %%
# sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

sns.displot(df['Age'], kind="kde")
plt.show()
plt.close()

# %%
df['Glucose'].hist()
# Out:
# <Axes: >

# %%
plt.scatter(df['BMI'], df['Glucose'])

# %%
df.boxplot(column='Insulin')
# Out:
# <Axes: >

# %%
sns.pairplot(df, hue='Outcome')

# %% [raw]
# # 📊 Histogram
#
# **What it shows:** Distribution of a single feature
#
# **Used for:**
#
# * Understanding data distribution
# * Detecting skewness
# * Finding outliers
#
# ---
#
# # 📦 Box Plot
#
# **What it shows:** Spread of data using quartiles (Q1, median, Q3)
#
# **Used for:**
#
# * Detecting outliers
# * Comparing distributions between groups
# * Understanding data spread
#
# ---
#
# # 🔵 Scatter Plot
#
# **What it shows:** Relationship between two variables
#
# **Used for:**
#
# * Detecting correlation
# * Visualizing clusters
# * Understanding feature relationships
#
# ---
#
# # 🔥 Correlation Heatmap
#
# **What it shows:** Correlation between multiple variables
#
# **Used for:**
#
# * Feature selection
# * Identifying strong/weak relationships
# * Detecting multicollinearity
#
# ---
#
# # 📈 Line Plot
#
# **What it shows:** Trend over time or sequence
#
# **Used for:**
#
# * Tracking model performance (loss, accuracy)
# * Time series analysis
# * Observing trends
#
# ---
#
# # 📊 Bar Chart
#
# **What it shows:** Comparison between categories
#
# **Used for:**
#
# * Class distribution
# * Feature importance
# * Comparing categorical data
#
# ---
#
# # 🎯 Pie Chart
#
# **What it shows:** Proportion of categories
#
# **Used for:**
#
# * Showing percentage distribution
# * Understanding class balance
#
# ---
#
# # 🧩 Pair Plot
#
# **What it shows:** Pairwise relationships between multiple variables
#
# **Used for:**
#
# * Visualizing feature interactions
# * Detecting patterns and clusters
# * Exploratory Data Analysis (EDA)
#
# ---
#
# # 📉 ROC Curve
#
# **What it shows:** Model performance (TPR vs FPR)
#
# **Used for:**
#
# * Evaluating classification models
# * Comparing models
# * Measuring separability
#
# ---
#
# # 🔲 Confusion Matrix
#
# **What it shows:** Prediction vs actual values
#
# **Used for:**
#
# * Evaluating classification performance
# * Identifying model errors
# * Calculating accuracy, precision, recall
#
# ---
#
# # 📌 Quick tip (important for exams/interviews)
#
# * **EDA (before model):**
#   Histogram, Box Plot, Scatter Plot, Heatmap
#
# * **Model evaluation:**
#   ROC Curve, Confusion Matrix, Line Plot
#
# ---
